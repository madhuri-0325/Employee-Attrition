# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [12,6]
sns.set_style('darkgrid')

# %%
data=pd.read_csv("HR_Employee_Attrition_Data.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               3
# 3                 3          4  Life Sciences              1               4
# 4                 2          1        Medical              1               5
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # EDA

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  2940.000000  2940.000000       2940.000000  2940.000000         2940.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.133819   403.440447          8.105485     1.023991            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     2940.000000              2940.000000  2940.000000     2940.000000
# mean      1470.500000                 2.721769    65.891156        2.729932
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.shape
# Out:
# (2940, 35)

# %%
# dropping zero variance columns emplo count and over18, and no use column employeenumber which is having sequence numbers,standatd hours alwas 80

df=data.copy()              
df=df.drop(['EmployeeCount','EmployeeNumber',"Over18","StandardHours"],axis=1)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (2940, 31)

# %%
df.info()                                    # no null values in data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       2940 non-null   int64
#  1   Attrition                 2940 non-null   object
#  2   BusinessTravel            2940 non-null   object
#  3   DailyRate                 2940 non-null   int64
#  4   Department                2940 non-null   object
#  5   DistanceFromHome          2940 non-null   int64
#  6   Education                 2940 non-null   int64
#  7   EducationField            2940 non-null   object
#  8   EnvironmentSatisfaction   2940 non-null   int64
#  9   Gender                    2940 non-null   object
#  10  HourlyRate                2940 non-null   int64
#  11  JobInvolvement            2940 non-null   int64
#  12  JobLevel                  2940 non-null   int64
#  13  JobRole                   2940 non-null   object
# ...

# %%
# percentage of attrition in each department
print("attrition percentage in company:",(len(df[df["Attrition"]=="Yes"])/len(df["Attrition"]))*100)
# Out:
# attrition percentage in company: 16.122448979591837

# %%
# percentage attrition in company
plt.figure(figsize=(10,4))
sns.countplot(x="Attrition", data=df,dodge=True)

"There is 16% attrition in the company "
# Out:
# 'There is 16% attrition in the company '

# %%
#plot between age and attrition
plt.figure(figsize=(10,4))
sns.countplot(x="Age", hue="Attrition", data=df,dodge=True)
"""employee with age range from 26 to 35 have more chance of taking attrition"""
# Out:
# 'employee with age range from 26 to 35 have more chance of taking attrition'

# %%
#plot between Business travel and age
plt.figure(figsize=(10,4))
sns.countplot(x="BusinessTravel", hue="Attrition" , data=df,dodge=True)
"""most of the employee who are travelling rarely not taking the attrition"""
# Out:
# 'most of the employee who are travelling rarely not taking the attrition'

# %%
sns.countplot(x="Department", data=df,dodge=True)
"""most of the employee are in from R&D department then followed by sales and Humanresources"""
# Out:
# 'most of the employee are in from R&D department then followed by sales and Humanresources'

# %%
# finding which department is getting more hike in salary
plt.figure(figsize=(12,4))
sns.countplot(x="Department", hue="PercentSalaryHike" , data=df,dodge=True)

""" most of the employee in R&D department is getting more hike(20 to 25%) compared to other departments """
# Out:
# ' most of the employee in R&D department is getting more hike(20 to 25%) compared to other departments '

# %%
print(len(df[df["Department"]=="Research & Development"]))
print(len(df[df["Department"]=="Sales"]))
print(len(df[df["Department"]=="Human Resources"]))
# Out:
# 1922
# 892
# 126

# %%
print(len(df[(df["Department"]=="Research & Development")& (df["Attrition"]=="Yes")]))
print(len(df[(df["Department"]=="Sales")& (df["Attrition"]=="Yes")]))
print(len(df[(df["Department"]=="Human Resources")& (df["Attrition"]=="Yes")]))
# Out:
# 266
# 184
# 24

# %%
# percentage of attrition in each department
print("Attrition percentage in R&D:",(len(df[(df["Department"]=="Research & Development") & (df["Attrition"]=="Yes")])/(len(df[df["Department"]=="Research & Development"])))*100)
print("Attrition percentage in Sales:",(len(df[(df["Department"]=="Sales") & (df["Attrition"]=="Yes")])/(len(df[df["Department"]=="Sales"])))*100)
print("Attrition percentage in Human Resources:",(len(df[(df["Department"]=="Human Resources") & (df["Attrition"]=="Yes")])/(len(df[df["Department"]=="Human Resources"])))*100)
# Out:
# Attrition percentage in R&D: 13.839750260145681
# Attrition percentage in Sales: 20.62780269058296
# Attrition percentage in Human Resources: 19.047619047619047

# %%
plt.figure(figsize=(10,4))
sns.countplot(x="Department", hue="Attrition" , data=df,dodge=True)
"""most of the attrition is from sales(20%) and human resources department(19%)
in R&D department it is 13%"""
# Out:
# 'most of the attrition is from sales(20%) and human resources department(19%)\nin R&D department it is 13%'

# %%
# percentage of attrition in each department
print("Attrition percentage in Sales Executive:",(len(df[(df["JobRole"]=="Sales Executive") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Sales Executive"])))*100)
print("Attrition percentage in Research Scientist:",(len(df[(df["JobRole"]=="Research Scientist") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Research Scientist"])))*100)
print("Attrition percentage in Laboratory Technician:",(len(df[(df["JobRole"]=="Laboratory Technician") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Laboratory Technician"])))*100)
print("Attrition percentage in Manufacturing Director:",(len(df[(df["JobRole"]=="Manufacturing Director") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Manufacturing Director"])))*100)
print("Attrition percentage in Healthcare Representative:",(len(df[(df["JobRole"]=="Healthcare Representative") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Healthcare Representative"])))*100)
print("Attrition percentage in Manager:",(len(df[(df["JobRole"]=="Manager") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Manager"])))*100)
print("Attrition percentage in Sales Representative:",(len(df[(df["JobRole"]=="Sales Representative") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Sales Representative"])))*100)
print("Attrition percentage in Research Director:",(len(df[(df["JobRole"]=="Research Director") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Research Director"])))*100)
print("Attrition percentage in Human Resources:",(len(df[(df["JobRole"]=="Human Resources") & (df["Attrition"]=="Yes")])/(len(df[df["JobRole"]=="Human Resources"])))*100)
# Out:
# Attrition percentage in Sales Executive: 17.484662576687114
# Attrition percentage in Research Scientist: 16.095890410958905
# Attrition percentage in Laboratory Technician: 23.93822393822394
# Attrition percentage in Manufacturing Director: 6.896551724137931
# Attrition percentage in Healthcare Representative: 6.870229007633588
# Attrition percentage in Manager: 4.901960784313726
# Attrition percentage in Sales Representative: 39.75903614457831
# Attrition percentage in Research Director: 2.5
# Attrition percentage in Human Resources: 23.076923076923077

# %%
# finding which job role is having more attrition

plt.figure(figsize=(16,4))
sns.countplot(x="JobRole", hue="Attrition" , data=df,dodge=True)
"""mostly sales representatives are taking attrition(39%) then Laboratory Technician(24%) then Human Resources(23%)"""
# Out:
# 'mostly sales representatives are taking attrition(39%) then Laboratory Technician(24%) then Human Resources(23%)'

# %%
print("Attrition percentage for envsatis-1:",(len(df[(df["EnvironmentSatisfaction"]==1) & (df["Attrition"]=="Yes")])/(len(df[df["EnvironmentSatisfaction"]==1])))*100)
print("Attrition percentage for envsatis-2:",(len(df[(df["EnvironmentSatisfaction"]==2) & (df["Attrition"]=="Yes")])/(len(df[df["EnvironmentSatisfaction"]==2])))*100)
print("Attrition percentage for envsatis-3:",(len(df[(df["EnvironmentSatisfaction"]==3) & (df["Attrition"]=="Yes")])/(len(df[df["EnvironmentSatisfaction"]==3])))*100)
print("Attrition percentage for envsatis-4:",(len(df[(df["EnvironmentSatisfaction"]==4) & (df["Attrition"]=="Yes")])/(len(df[df["EnvironmentSatisfaction"]==4])))*100)
# Out:
# Attrition percentage for envsatis-1: 25.352112676056336
# Attrition percentage for envsatis-2: 14.982578397212542
# Attrition percentage for envsatis-3: 13.686534216335541
# Attrition percentage for envsatis-4: 13.452914798206278

# %%
#finding role of environment satisfaction in attrition

plt.figure(figsize=(16,4))
sns.countplot(x="EnvironmentSatisfaction", hue="Attrition" , data=df,dodge=True)

""" employee with 1 environment satisfaction is having high attrition"""
# Out:
# ' employee with 1 environment satisfaction is having high attrition'

# %%
# role of gender in attrition
print("Attrition percentage for Female:",(len(df[(df["Gender"]=="Female") & (df["Attrition"]=="Yes")])/(len(df[df["Gender"]=="Female"])))*100)
print("Attrition percentage for Male:",(len(df[(df["Gender"]=="Male") & (df["Attrition"]=="Yes")])/(len(df[df["Gender"]=="Male"])))*100)
# Out:
# Attrition percentage for Female: 14.795918367346939
# Attrition percentage for Male: 17.006802721088434

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="Gender", hue="Attrition" , data=df,dodge=True)

" Male employee attrition is high compared to female employee attrition"
# Out:
# ' Male employee attrition is high compared to female employee attrition'

# %%
# salaryhike effect on attrition
print("Attrition percentage for hike-11:",(len(df[(df["PercentSalaryHike"]==11) & (df["Attrition"]=="Yes")])/(len(df[df["PercentSalaryHike"]==11])))*100)
print("Attrition percentage for hike-15:",(len(df[(df["PercentSalaryHike"]==15) & (df["Attrition"]=="Yes")])/(len(df[df["PercentSalaryHike"]==15])))*100)
print("Attrition percentage for hike-20:",(len(df[(df["PercentSalaryHike"]==20) & (df["Attrition"]=="Yes")])/(len(df[df["PercentSalaryHike"]==20])))*100)
print("Attrition percentage for hike-25:",(len(df[(df["PercentSalaryHike"]==25) & (df["Attrition"]=="Yes")])/(len(df[df["PercentSalaryHike"]==25])))*100)
# Out:
# Attrition percentage for hike-11: 19.523809523809526
# Attrition percentage for hike-15: 17.82178217821782
# Attrition percentage for hike-20: 12.727272727272727
# Attrition percentage for hike-25: 5.555555555555555

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="PercentSalaryHike", hue="Attrition" , data=df,dodge=True)
""" employee who are getting less hike are having high attrition"""
# Out:
# ' employee who are getting less hike are having high attrition'

# %%
#jobsatisfaction role in attrition

print("Attrition percentage for jobsatis-1:",(len(df[(df["JobSatisfaction"]==1) & (df["Attrition"]=="Yes")])/(len(df[df["JobSatisfaction"]==1])))*100)
print("Attrition percentage for jobsatis-2:",(len(df[(df["JobSatisfaction"]==2) & (df["Attrition"]=="Yes")])/(len(df[df["JobSatisfaction"]==2])))*100)
print("Attrition percentage for jobsatis-3:",(len(df[(df["JobSatisfaction"]==3) & (df["Attrition"]=="Yes")])/(len(df[df["JobSatisfaction"]==3])))*100)
print("Attrition percentage for jobsatis-4:",(len(df[(df["JobSatisfaction"]==4) & (df["Attrition"]=="Yes")])/(len(df[df["JobSatisfaction"]==4])))*100)
# Out:
# Attrition percentage for jobsatis-1: 22.837370242214533
# Attrition percentage for jobsatis-2: 16.428571428571427
# Attrition percentage for jobsatis-3: 16.515837104072396
# Attrition percentage for jobsatis-4: 11.328976034858387

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="JobSatisfaction", hue="Attrition" , data=df,dodge=True)

""" employee with less jobsatisfaction is having high attrition"""
# Out:
# ' employee with less jobsatisfaction is having high attrition'

# %%
#performance vs hike
plt.figure(figsize=(12,4))
sns.countplot(x="PerformanceRating", hue="PercentSalaryHike" , data=df)
""" employee with performance rating 4 are having high hike(20 to 25%) and 
most of employee with performance rating 3 are having less hike(11-15%)"""
# Out:
# ' employee with performance rating 4 are having high hike(20 to 25%) and \nmost of employee with performance rating 3 are having less hike(11-15%)'

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="YearsAtCompany", hue="Attrition" , data=df)

""" employee who are staying more than 15 years in company have zero attrition"""
# Out:
# ' employee who are staying more than 15 years in company have zero attrition'

# %% [markdown]
# # Data cleaning

# %%
from sklearn import preprocessing

# %%
def preprocessor(df):
    res_df = df.copy()
    le = preprocessing.LabelEncoder()
    
    res_df['Attrition'] = le.fit_transform(res_df['Attrition'])
    res_df['BusinessTravel'] = le.fit_transform(res_df['BusinessTravel'])
    res_df['Department'] = le.fit_transform(res_df['Department'])
    res_df['EducationField'] = le.fit_transform(res_df['EducationField'])
    res_df['Gender'] = le.fit_transform(res_df['Gender'])
    res_df['JobRole'] = le.fit_transform(res_df['JobRole'])
    res_df['MaritalStatus'] = le.fit_transform(res_df['MaritalStatus'])
    res_df['OverTime'] = le.fit_transform(res_df['OverTime'])
    
    return res_df

# %%
en_df = preprocessor(df)
en_df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
plt.figure(figsize=(15,15))                              # finding the correlated variables
sns.heatmap(en_df.corr(),annot=True)

"""monthlyincome and joblevel are very highly correlated, monthlyincome and totalworking years are highly crrelated it means all theree are highly correlated we can remove any two of them
performance rating and percent salary hike are highly corr, we can remove any one
years at company and years in current role and years with current manager are highly correlated, we can remove any two of them
keeping monthlyincome, percentsalaryhike, years at company for further analysis."""
# Out:
# 'monthlyincome and joblevel are very highly crrelated, monthlyincome and totalworking years are highly crrelated it means all theree are highly correlated we can remove any two of them\nperformance rating and percent salary hike are highly corr, we can remove any one\nyears at company and years in current role and years with current manager are highly correlated, we can remove any two of them\nkeeping monthlyincome, percentsalaryhike, years at company for further analysis.'

# %%
#dropping highly correlated variables
en_df=en_df.drop(['JobLevel','TotalWorkingYears',"PerformanceRating","YearsInCurrentRole","YearsWithCurrManager"],axis=1)
en_df.shape
# Out:
# (2940, 26)

# %%
df_std = preprocessing.scale(en_df)       # some variable values are high so performing standardization to make the data std normal 
df_std = pd.DataFrame(df_std)
df_std.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.446350  2.280906  0.590048  0.742527  1.401512 -1.010909 -0.891688
# 1  1.322365 -0.438422 -0.913194 -1.297775 -0.493817 -0.147150 -1.868426
# 2  0.008343  2.280906  0.590048  1.414363 -0.493817 -0.887515 -0.891688
# 3 -0.429664 -0.438422 -0.913194  1.461466 -0.493817 -0.764121  1.061787
# 4 -1.086676 -0.438422  0.590048 -0.524295 -0.493817 -0.887515 -1.868426
#
#          7         8         9   ...        16        17        18        19  \
# 0 -0.937414 -0.660531 -1.224745  ...  0.726020  2.125136  1.591746 -1.150554
# 1 -0.937414  0.254625  0.816497  ...  1.488876 -0.678049 -0.628241  2.129306
# 2  1.316673  1.169781  0.816497  ... -1.674841  1.324226  1.591746 -0.057267
# 3 -0.937414  1.169781 -1.224745  ...  1.243211 -0.678049  1.591746 -1.150554
# 4  0.565311 -1.575686  0.816497  ...  0.325900  2.525591 -0.628241 -0.877232
#
#          20        21        22        23        24        25
# ...

# %%
features=en_df.columns.values
features
# Out:
# array(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsSinceLastPromotion'], dtype=object)

# %%
df_std = df_std.rename(index = str, columns = {0:'Age',1: 'Attrition',2: 'BusinessTravel', 
                         3: 'DailyRate', 4: 'Department',5: 'DistanceFromHome',6:"Education",7:"EducationField",
                         8:'EnvironmentSatisfaction', 9: 'Gender', 
                         10: 'HourlyRate', 11:'JobInvolvement', 12: 'JobRole', 13: 'JobSatisfaction',14:"MaritalStatus",
                         15:"MonthlyIncome",16:"MonthlyRate",17:"NumCompaniesWorked",18:"OverTime",19:"PercentSalaryHike",
                         20:"RelationshipSatisfaction",21:"StockOptionLevel",22:"TrainingTimesLastYear",23:"WorkLifeBalance",
                         24:"YearsAtCompany",25:"YearsSinceLastPromotion"})
df_std.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.446350   2.280906        0.590048   0.742527    1.401512
# 1  1.322365  -0.438422       -0.913194  -1.297775   -0.493817
# 2  0.008343   2.280906        0.590048   1.414363   -0.493817
# 3 -0.429664  -0.438422       -0.913194   1.461466   -0.493817
# 4 -1.086676  -0.438422        0.590048  -0.524295   -0.493817
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0         -1.010909  -0.891688       -0.937414                -0.660531
# 1         -0.147150  -1.868426       -0.937414                 0.254625
# 2         -0.887515  -0.891688        1.316673                 1.169781
# 3         -0.764121   1.061787       -0.937414                 1.169781
# 4         -0.887515  -1.868426        0.565311                -1.575686
#
#      Gender  ...  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0 -1.224745  ...     0.726020            2.125136  1.591746
# ...

# %%
# outlier detection
ax = df_std[features].plot(kind='box', title='boxplot')

# Display the plot
plt.show()                                   # before removing outliers

# %%
df1=df_std.copy()

# %%
# eliminating ouliers with zscores technique (above 2 standard deviations all are considered as outliers)
def zscorerem(df,cols,thr):
    for col in cols:
        mean=df1[col].mean()
        #med=house1[col].median()
        std=df1[col].std()
        ub=mean+(thr*std)
        lb=mean-(thr*std)
        df1[col]=np.where(df1[col]>ub,ub,
                           np.where(df1[col]<lb,lb,df1[col]))
        
    return df1

# %%
df_f=zscorerem(df_std,features,2)

# %%
# outlier detection
ax = df_f[features].plot(kind='box', title='boxplot')

# Display the plot
plt.show()                                # after removing outliers

# %%
x = en_df.drop(['Attrition'],axis =1).values
y = en_df['Attrition'].values                         #separating dep and indep variables

# %% [markdown]
# # Decision tree classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size =0.2)             #splitting the data set

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (2352, 25)
# (2352,)

# %%
import time
import random
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV

# %%
# DecisionTree
model_dt = DecisionTreeClassifier(random_state=1, max_depth=16,min_samples_split=2,min_samples_leaf=1, criterion='entropy')
model_dt.fit(x_train, y_train)
model_dt_score_train = model_dt.score(x_train, y_train)
print("Training score: ",model_dt_score_train)
model_dt_score_test = model_dt.score(x_test, y_test)
print("Testing score: ",model_dt_score_test)
# Out:
# Training score:  0.9961734693877551
# Testing score:  0.9506802721088435

# %%
#gridsearchcv
start = time.time()

param_dist = {'max_depth': [14,15,16,17,18],
              'min_samples_split': [1,2,3,4,],
              'min_samples_leaf':[1,2,3,4,5],
              
              'criterion': ['gini','entropy']
              }

cv_rf = GridSearchCV(model_dt, cv = 10,
                     param_grid=param_dist, 
                     n_jobs = 3)

cv_rf.fit(x_train, y_train)
print('Best Parameters using grid search: \n', cv_rf.best_params_)
end = time.time()
print('Time taken in grid search: {0: .2f}'.format(end - start))
# Out:
# Best Parameters using grid search:
#  {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Time taken in grid search:  16.54
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan 0.92898305 0.92983592 0.924304          nan 0.89964659
#  0.89964659 0.89964659        nan 0.88050847 0.88050847 0.88050847
#         nan 0.87967003 0.87967003 0.87967003        nan 0.86649477
#  0.86649477 0.86649477        nan 0.93536423 0.93579156 0.9268626
#         nan 0.90092138 0.90092138 0.90092138        nan 0.88050667
#  0.88050667 0.88050667        nan 0.87966823 0.87966823 0.87966823
#         nan 0.86479625 0.86479625 0.86479625        nan 0.93664623
#  0.93664803 0.92729354        nan 0.90304724 0.90304724 0.90304724
#         nan 0.88008475 0.88008475 0.88008475        nan 0.87754418
#  0.87754418 0.87754418        nan 0.8681969  0.8681969  0.8681969
# ...

# %%
#performance metrics

y_pred_dt=model_dt.predict(x_test)
fpr_dt, tpr_dt, _ = roc_curve(y_test, y_pred_dt)
roc_auc_dt = auc(fpr_dt, tpr_dt)
print("AUC:",roc_auc_dt)
# Out:
# AUC: 0.8903228026705211

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test,y_pred_dt))
print("Recall:",metrics.recall_score(y_test,y_pred_dt))
print("Precision:",metrics.precision_score(y_test,y_pred_dt))
# Out:
# Accuracy: 0.9506802721088435
# Recall: 0.8045977011494253
# Precision: 0.8536585365853658

# %%
print (confusion_matrix(y_test,y_pred_dt ))               # 16 misclassifications
# Out:
# [[489  12]
#  [ 17  70]]

# %% [markdown]
# # Random Forest

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
fit_rf = RandomForestClassifier(random_state=42)

# %%
np.random.seed(42)
start = time.time()

param_dist = {'max_depth': [12,13,14,15],
              'bootstrap': [True, False],
              'max_features': ['auto', 'sqrt', 'log2', None],
              'criterion': ['gini', 'entropy']
              }

cv_rf = GridSearchCV(fit_rf, cv = 10,
                     param_grid=param_dist, 
                     n_jobs = 3)

cv_rf.fit(x_train, y_train)
print('Best Parameters using grid search: \n', cv_rf.best_params_)
end = time.time()
print('Time taken in grid search: {0: .2f}'.format(end - start))
# Out:
# Best Parameters using grid search:
#  {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 14, 'max_features': 'auto'}
# Time taken in grid search:  283.53

# %%
# Set best parameters given by grid search 
fit_rf.set_params(criterion = 'entropy',
                  max_features = 'auto', 
                  max_depth = 14)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=14, random_state=42)

# %%
fit_rf.set_params(warm_start=True, 
                  oob_score=True)

min_estimators = 15
max_estimators = 1000

error_rate = {}

for i in range(min_estimators, max_estimators + 1):
    fit_rf.set_params(n_estimators=i)
    fit_rf.fit(x_train, y_train)

    oob_error = 1 - fit_rf.oob_score_
    error_rate[i] = oob_error
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:541: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:545: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:541: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:545: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /

# %%
# Convert dictionary to a pandas series for easy plotting 
oob_series = pd.Series(error_rate)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.set_facecolor('#fafafa')

oob_series.plot(kind='line',color = 'red')
plt.axhline(0.055, color='#875FDB',linestyle='--')
plt.axhline(0.05, color='#875FDB',linestyle='--')
plt.xlabel('n_estimators')
plt.ylabel('OOB Error Rate')
plt.title('OOB Error Rate Across various Forest sizes \n(From 15 to 1000 trees)')
# Out:
# Text(0.5, 1.0, 'OOB Error Rate Across various Forest sizes \n(From 15 to 1000 trees)')

# %%
# Refine the tree via OOB Output
fit_rf.set_params(n_estimators=500,
                  bootstrap = True,
                  warm_start=False, 
                  oob_score=False)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=14, n_estimators=500,
#                        random_state=42)

# %%
fit_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=14, n_estimators=500,
#                        random_state=42)

# %%
def variable_importance(fit):
    """
    Purpose
    ----------
    Checks if model is fitted CART model then produces variable importance
    and respective indices in dictionary.

    Parameters
    ----------
    * fit:  Fitted model containing the attribute feature_importances_

    Returns
    ----------
    Dictionary containing arrays with importance score and index of columns
    ordered in descending order of importance.
    """
    try:
        if not hasattr(fit, 'fit'):
            return print("'{0}' is not an instantiated model from scikit-learn".format(fit)) 

        # Captures whether the model has been trained
        if not vars(fit)["estimators_"]:
            return print("Model does not appear to be trained.")
    except KeyError:
        print("Model entered does not contain 'estimators_' attribute.")

    importances = fit.feature_importances_
    indices = np.argsort(importances)[::-1]
    return {'importance': importances,
            'index': indices}

# %%
var_imp_rf = variable_importance(fit_rf)

importances_rf = var_imp_rf['importance']

indices_rf = var_imp_rf['index']

# %%
def print_var_importance(importance, indices, name_index):
    """
    Purpose
    ----------
    Prints dependent variable names ordered from largest to smallest
    based on information gain for CART model.
    Parameters
    ----------
    * importance: Array returned from feature_importances_ for CART
                models organized by dataframe index
    * indices: Organized index of dataframe from largest to smallest
                based on feature_importances_
    * name_index: Name of columns included in model

    Returns
    ----------
    Prints feature importance in descending order
    """
    print("Feature ranking:")

    for f in range(0, indices.shape[0]):
        i = f
        print("{0}. The feature '{1}' has a Mean Decrease in Impurity of {2:.5f}"
              .format(f + 1,
                      names_index[indices[i]],
                      importance[indices[f]]))

# %%
en_df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsSinceLastPromotion'],
#       dtype='object')

# %%
names_index=['Age','BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
       'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
       'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsSinceLastPromotion']

# %%
print_var_importance(importances_rf, indices_rf, names_index)
# Out:
# Feature ranking:
# 1. The feature 'MonthlyIncome' has a Mean Decrease in Impurity of 0.10608
# 2. The feature 'Age' has a Mean Decrease in Impurity of 0.07722
# 3. The feature 'DailyRate' has a Mean Decrease in Impurity of 0.06562
# 4. The feature 'MonthlyRate' has a Mean Decrease in Impurity of 0.05947
# 5. The feature 'OverTime' has a Mean Decrease in Impurity of 0.05923
# 6. The feature 'YearsAtCompany' has a Mean Decrease in Impurity of 0.05824
# 7. The feature 'HourlyRate' has a Mean Decrease in Impurity of 0.05520
# 8. The feature 'DistanceFromHome' has a Mean Decrease in Impurity of 0.05417
# 9. The feature 'JobRole' has a Mean Decrease in Impurity of 0.04063
# 10. The feature 'PercentSalaryHike' has a Mean Decrease in Impurity of 0.04028
# 11. The feature 'EnvironmentSatisfaction' has a Mean Decrease in Impurity of 0.03527
# 12. The feature 'NumCompaniesWorked' has a Mean Decrease in Impurity of 0.03525
# ...

# %%
def variable_importance_plot(importance, indices, name_index):
    """
    Purpose
    ----------
    Prints bar chart detailing variable importance for CART model
    NOTE: feature_space list was created because the bar chart
    was transposed and index would be in incorrect order.

    Parameters
    ----------
    * importance: Array returned from feature_importances_ for CART
                models organized by dataframe index
    * indices: Organized index of dataframe from largest to smallest
                based on feature_importances_
    * name_index: Name of columns included in model

    Returns:
    ----------
    Returns variable importance plot in descending order
    """
    index = np.arange(len(names_index))

    importance_desc = sorted(importance)
    feature_space = []
    for i in range(indices.shape[0] - 1, -1, -1):
        feature_space.append(names_index[indices[i]])

    fig, ax = plt.subplots(figsize=(10, 10))

    #ax.set_axis_bgcolor('#fafafa')
    plt.title('Feature importances for Random Forest Model\
    \nAttrition in company')
    plt.barh(index,
             importance_desc,
             align="center",
             color = '#875FDB')
    plt.yticks(index,
               feature_space)

    plt.ylim(-1, 30)
    plt.xlim(0, max(importance_desc) + 0.01)
    plt.xlabel('Mean Decrease in Impurity')
    plt.ylabel('Feature')

    plt.show()
    plt.close()

# %%
plt.style.use('ggplot')
pd.set_option('display.max_columns', 500) 

variable_importance_plot(importances_rf, indices_rf, names_index)
""" most important variable for Attrition is monthlyincome"""

# %%
predictions_rf = fit_rf.predict(x_test)

# %%
#performance metrics


fpr_rf, tpr_rf, _ = roc_curve(y_test, predictions_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)
print("AUC:",roc_auc_rf)
# Out:
# AUC: 0.9137931034482758

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test,predictions_rf))
print("Recall:",metrics.recall_score(y_test,predictions_rf))
print("Precision:",metrics.precision_score(y_test,predictions_rf))
# Out:
# Accuracy: 0.9744897959183674
# Recall: 0.8275862068965517
# Precision: 1.0

# %%
print (confusion_matrix(y_test,predictions_rf )) 

"""RF is giving good performance than DT"""
# Out:
# [[501   0]
#  [ 15  72]]

# %% [markdown]
# # KNN

# %%
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()  
scaler.fit(x_train)

X_train = scaler.transform(x_train)  
X_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier 

classifier = KNeighborsClassifier(n_neighbors=57,metric='manhattan')  
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=57)

# %%
 knn = KNeighborsClassifier()

np.random.seed(42)
start = time.time()

param_dist = {'n_neighbors':[40,50,60,70],
             'metric':['eucleadian','manhattan']}
              

cv_rf = GridSearchCV( knn, cv = 10,
                     param_grid=param_dist, 
                     n_jobs = 3)

cv_rf.fit(X_train, y_train)
print('Best Parameters using grid search: \n', cv_rf.best_params_)
end = time.time()
print('Time taken in grid search: {0: .2f}'.format(end - start))
# Out:
# Best Parameters using grid search:
#  {'metric': 'manhattan', 'n_neighbors': 60}
# Time taken in grid search:  55.69
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.8384331  0.83843491
#  0.83886044 0.83801118]
#   warnings.warn(

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test, y_pred))  
print(classification_report(y_test, y_pred)) 

""" KNN is able to classify class 0 but not able to classify class 1"""
# Out:
# [[501   0]
#  [ 83   4]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       501
#            1       1.00      0.05      0.09        87
#
#     accuracy                           0.86       588
#    macro avg       0.93      0.52      0.51       588
# weighted avg       0.88      0.86      0.80       588
# ' KNN is able to classify class 0 but not able to classify class 1'

# %%
error = []

# Calculating error for K values between 1 and 40
for i in range(50, 70):  
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(12, 6))  
plt.plot(range(50, 70), error, color='red', linestyle='dashed', marker='o',  
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')  
plt.xlabel('K Value')  
plt.ylabel('Mean Error')  
plt.show()

# %%
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.858843537414966

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# instantiate the model (using the default parameters)
logreg = LogisticRegression()
# fit the model with data
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logreg.predict(X_test)

# %%
fpr_rf, tpr_rf, _ = roc_curve(y_test,y_pred)
roc_auc_rf = auc(fpr_rf, tpr_rf)
print("AUC:",roc_auc_rf)
# Out:
# AUC: 0.6631908596599904

# %%
print(confusion_matrix(y_test, y_pred))  
print(classification_report(y_test, y_pred))
# Out:
# [[486  15]
#  [ 56  31]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       501
#            1       0.67      0.36      0.47        87
#
#     accuracy                           0.88       588
#    macro avg       0.79      0.66      0.70       588
# weighted avg       0.86      0.88      0.86       588

# %%
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.8792517006802721

# %% [markdown]
# # SVM

# %% [markdown]
# ## Linear Kernal

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc=SVC() #Default hyperparameters
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9166666666666666

# %% [markdown]
# ## Polynomial Kernel

# %%
svc=SVC(kernel='poly')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
""" Accuracy increased it means it is non linear data"""
# Out:
# Accuracy Score:
# 0.9336734693877551

# %%
svc=SVC(kernel='rbf')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
""" Accuracy increased it means it is non linear data"""
# Out:
# Accuracy Score:
# 0.9166666666666666
# ' Accuracy increased it means it is non linear data'

# %%
# optimizing

# %%
### finding optimal parameters with GridsearchCV
svm_model= SVC()
tuned_parameters = {
 'C': [2.5,3,3.5], 
'kernel': ['poly','rbf','linear'],
 'gamma': [0.01,0.1,1]    
 }

model_svm = GridSearchCV(svm_model, tuned_parameters,cv=10,scoring='accuracy')
model_svm.fit(X_train, y_train)
print(model_svm.best_score_)
print(model_svm.best_params_)
# Out:
# 0.9621565091958167
# {'C': 2.9, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
### finding optimal parameters with GridsearchCV
svm_model= SVC()
tuned_parameters = {
 'C': (np.arange(2.5,3.2,0.1)) , 'kernel': ['linear','rbf','poly'],
 'C': (np.arange(2.5,3.2,0.1)) , 'gamma': [0.08,0.09,0.1,0.2,0.3], 'kernel': ['rbf'],    
 'gamma':[0.08,0.09,0.1,0.2,0.3], 'C':(np.arange(2.5,3.2,0.1)) , 'kernel':['poly','rbf','linear']
                   }
model_svm = GridSearchCV(svm_model, tuned_parameters,cv=10,scoring='accuracy')
model_svm.fit(X_train, y_train)
print(model_svm.best_score_)
print(model_svm.best_params_)
# Out:
# 0.9621565091958167
# {'C': 2.9000000000000004, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svc=SVC(kernel='rbf',gamma= 0.1,C=2.9000000000000004)
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9761904761904762

# %%
fpr_rf, tpr_rf, _ = roc_curve(y_test,y_pred)
roc_auc_rf = auc(fpr_rf, tpr_rf)
print("AUC:",roc_auc_rf)
# Out:
# AUC: 0.9290384747745888

# %%
print(confusion_matrix(y_test, y_pred))  
print(classification_report(y_test, y_pred))
"""SVM giving the best results compared to DT,RF,KNN,Logistic regression"""
# Out:
# [[499   2]
#  [ 12  75]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       501
#            1       0.97      0.86      0.91        87
#
#     accuracy                           0.98       588
#    macro avg       0.98      0.93      0.95       588
# weighted avg       0.98      0.98      0.98       588

# %% [markdown]
# ## Best performing model is SVM, then RF and worst performing model is KNN
